# %%
#Import Dependencies
import pandas as pd
import numpy as np

# %%
file = "Resources/listings.csv"

df = pd.read_csv(file)
columns_to_keep = ["zipcode", "room_type", "accommodates", "bedrooms", "bathrooms", "beds", "minimum_nights", "number_of_reviews", "price"]
df = df[columns_to_keep]

#drop all rows with nulls
df.dropna(how='any', inplace=True)

#make copy of df to avoid warning errors
data_df = df.copy()

# price is a string.  Remove $ and convert into float
# https://stackoverflow.com/questions/32464280/converting-currency-with-to-numbers-in-python-pandas
data_df["price"] = data_df["price"].replace('[\$,]', '', regex=True).astype(float)

#there is one row where they have "CA" for zipcode.  Drop that row.
data_df=data_df[data_df.zipcode != "CA"]

#drop hotel room from room_type
data_df=data_df[data_df.room_type != "Hotel room"]

#some zipcodes start with CA.  replace "CA " with "" 
#https://stackoverflow.com/questions/13682044/remove-unwanted-parts-from-strings-in-a-column
data_df["zipcode"] = data_df["zipcode"].replace('CA ', '', regex=True)

#drop all rows with nulls
data_df.dropna(how='any', inplace=True)

#convert zipcodes to intergers - ask justin if we need to do this?????
data_df["zipcode"] = data_df["zipcode"].astype(str).astype(int)

#we only want to keep prices below $500.  Everything about $500 is an outlier
data_df = data_df[data_df.price < 500]

data_df.head()
# Out:
#    zipcode        room_type  accommodates  bedrooms  bathrooms  beds  \
# 0    94117  Entire home/apt             3       1.0        1.0   2.0
# 1    94110  Entire home/apt             5       2.0        1.0   3.0
# 2    94117     Private room             2       1.0        4.0   1.0
# 3    94117     Private room             2       1.0        4.0   1.0
# 5    94110     Private room             3       1.0        1.0   1.0
#
#    minimum_nights  number_of_reviews  price
# 0               1                240  170.0
# 1              30                111  235.0
# 2              32                 19   65.0
# 3              32                  8   65.0
# 5               1                736  139.0

# %%
data_df.dtypes
# Out:
# zipcode                int32
# room_type             object
# accommodates           int64
# bedrooms             float64
# bathrooms            float64
# beds                 float64
# minimum_nights         int64
# number_of_reviews      int64
# price                float64
# dtype: object

# %%
#create price bins.  TA recommended 15 bins.  each bin is increments of $36
bins = [0]
bin_names = []

for i in range (0,14):
    x = (i * 36) + 36
    bins.append(x)
    name = "bin " + str(i*36) + "-" + str(x)
    bin_names.append(name)
    
print(bins, bin_names)
print(len(bins), len(bin_names))
# Out:
# [0, 36, 72, 108, 144, 180, 216, 252, 288, 324, 360, 396, 432, 468, 504] ['bin 0-36', 'bin 36-72', 'bin 72-108', 'bin 108-144', 'bin 144-180', 'bin 180-216', 'bin 216-252', 'bin 252-288', 'bin 288-324', 'bin 324-360', 'bin 360-396', 'bin 396-432', 'bin 432-468', 'bin 468-504']
# 15 14

# %%
#cut the bins and group names to the dataframe

data_df["price_bin"] = pd.cut(data_df["price"], bins, labels=bin_names)
data_df.head(25)
# Out:
#     zipcode        room_type  accommodates  bedrooms  bathrooms  beds  \
# 0     94117  Entire home/apt             3       1.0        1.0   2.0
# 1     94110  Entire home/apt             5       2.0        1.0   3.0
# 2     94117     Private room             2       1.0        4.0   1.0
# 3     94117     Private room             2       1.0        4.0   1.0
# 5     94110     Private room             3       1.0        1.0   1.0
# 6     94107     Private room             2       1.0        1.0   1.0
# 7     94110  Entire home/apt             4       2.0        1.0   3.0
# 8     94109  Entire home/apt             2       0.0        1.0   1.0
# 9     94117  Entire home/apt             3       3.0        1.0   3.0
# 10    94102  Entire home/apt             5       3.0        2.0   3.0
# 11    94102  Entire home/apt             2       1.0        1.5   1.0
# 12    94117     Private room             2       1.0        3.0   2.0
# 13    94117     Private room             2       1.0        3.0   2.0
# 14    94114     Private room             1       1.0        1.0   1.0
# 15    94117  Entire home/apt             4       2.0        1.0   3.0
# 16    94105  Entire home/apt             4       2.0        2.0   2.0
# 17    94114  Entire home/apt             3       0.0        1.0   1.0
# 18    94117     Private room             2       1.0        1.0   1.0
# 19    94133  Entire home/apt             2       1.0        1.0   1.0
# 20    94117     Private room             2       1.0        4.0   1.0
# 21    94114  Entire home/apt             2       1.0        1.0   1.0
# 22    94107     Private room             2       1.0        1.0   1.0
# 23    94117     Private room             1       1.0        1.0   1.0
# 24    94115  Entire home/apt             4       1.0        1.0   1.0
# 25    94131     Private room             2       1.0        1.0   1.0
#
#     minimum_nights  number_of_reviews  price    price_bin
# 0                1                240  170.0  bin 144-180
# 1               30                111  235.0  bin 216-252
# 2               32                 19   65.0    bin 36-72
# 3               32                  8   65.0    bin 36-72
# 5                1                736  139.0  bin 108-144
# 6                1                531  135.0  bin 108-144
# 7               30                337  150.0  bin 144-180
# 8               30                 18  120.0  bin 108-144
# 9               30                 37  177.0  bin 144-180
# 10              30                 15  110.0  bin 108-144
# 11              30                 20  121.0  bin 108-144
# 12              32                  6   85.0   bin 72-108
# 13              32                  5   85.0   bin 72-108
# 14               3                427   79.0   bin 72-108
# 15              30                 17  117.0  bin 108-144
# 16              30                 14  450.0  bin 432-468
# 17              30                 63  107.0   bin 72-108
# 18               2                415  110.0  bin 108-144
# 19              30                119  125.0  bin 108-144
# 20              32                 14   65.0    bin 36-72
# 21               3                412  155.0  bin 144-180
# 22               2                306  135.0  bin 108-144
# 23               1                204   79.0   bin 72-108
# 24               5                332  225.0  bin 216-252
# 25               5                 42  150.0  bin 144-180

# %%
data_df.to_csv("Output/cleaned_data.csv", index = False)
