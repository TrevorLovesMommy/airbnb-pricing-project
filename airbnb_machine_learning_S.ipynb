# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from sklearn) (0.21.3)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from scikit-learn->sklearn) (0.14.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.17.3)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.3.1)

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (0.14.0)

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("listings_final.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#    zipcode        room_type  accommodates  bathrooms  bedrooms  beds  \
# 0  94117.0  Entire home/apt             3        1.0       1.0   2.0
# 1  94110.0  Entire home/apt             5        1.0       2.0   3.0
# 2  94117.0     Private room             2        4.0       1.0   1.0
# 3  94117.0     Private room             2        4.0       1.0   1.0
# 4  94117.0  Entire home/apt             4        1.5       2.0   2.0
#
#    bed_type    price  minimum_nights  number_of_reviews
# 0  Real Bed  $170.00               1                240
# 1  Real Bed  $235.00              30                111
# 2  Real Bed   $65.00              32                 19
# 3  Real Bed   $65.00              32                  8
# 4  Real Bed  $703.00               5                 28

# %%
df.dtypes
# Out:
# zipcode              float64
# room_type             object
# accommodates           int64
# bathrooms            float64
# bedrooms             float64
# beds                 float64
# bed_type              object
# price                 object
# minimum_nights         int64
# number_of_reviews      int64
# dtype: object

# %%
#converting column price which is an object to int
df['price'] = df['price'].replace('[\$\,\.]', '', regex=True).astype(int)
df['price'].head()
# Out:
# 0    17000
# 1    23500
# 2     6500
# 3     6500
# 4    70300
# Name: price, dtype: int64

# %%
df.groupby(['zipcode']).count()
# Out:
#          room_type  accommodates  bathrooms  bedrooms  beds  bed_type  price  \
# zipcode
# 94014.0         34            34         34        34    34        34     34
# 94102.0        548           548        548       548   548       548    548
# 94103.0        514           514        514       514   514       514    514
# 94104.0         18            18         18        18    18        18     18
# 94105.0        155           155        155       155   155       155    155
# 94107.0        410           410        410       410   410       410    410
# 94108.0        331           331        331       331   331       331    331
# 94109.0        680           680        680       680   680       680    680
# 94110.0        920           920        920       920   920       920    920
# 94111.0         71            71         71        71    71        71     71
# 94112.0        376           376        376       376   376       376    376
# 94113.0          1             1          1         1     1         1      1
# 94114.0        632           632        632       632   632       632    632
# 94115.0        307           307        307       307   307       307    307
# 94116.0        202           202        202       202   202       202    202
# 94117.0        665           665        665       665   665       665    665
# 94118.0        222           222        222       222   222       222    222
# 94121.0        191           191        191       191   191       191    191
# 94122.0        341           341        341       341   341       341    341
# 94123.0        206           206        206       206   206       206    206
# 94124.0        207           207        207       207   207       207    207
# 94127.0        134           134        134       134   134       134    134
# 94130.0          1             1          1         1     1         1      1
# 94131.0        269           269        269       269   269       269    269
# 94132.0         84            84         84        84    84        84     84
# 94133.0        328           328        328       328   328       328    328
# 94134.0        147           147        147       147   147       147    147
# 94158.0         82            82         82        82    82        82     82
#
#          minimum_nights  number_of_reviews
# zipcode
# 94014.0              34                 34
# 94102.0             548                548
# 94103.0             514                514
# 94104.0              18                 18
# 94105.0             155                155
# 94107.0             410                410
# 94108.0             331                331
# 94109.0             680                680
# 94110.0             920                920
# 94111.0              71                 71
# 94112.0             376                376
# 94113.0               1                  1
# 94114.0             632                632
# 94115.0             307                307
# 94116.0             202                202
# 94117.0             665                665
# 94118.0             222                222
# 94121.0             191                191
# 94122.0             341                341
# 94123.0             206                206
# 94124.0             207                207
# 94127.0             134                134
# 94130.0               1                  1
# 94131.0             269                269
# 94132.0              84                 84
# 94133.0             328                328
# 94134.0             147                147
# 94158.0              82                 82

# %%
df.dtypes
# Out:
# zipcode              float64
# room_type             object
# accommodates           int64
# bathrooms            float64
# bedrooms             float64
# beds                 float64
# bed_type              object
# price                  int64
# minimum_nights         int64
# number_of_reviews      int64
# dtype: object

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
target = df["price"]
data = df.drop("price", axis=1)
feature_names = data.columns
data.head()
# Out:
#    zipcode        room_type  accommodates  bathrooms  bedrooms  beds  \
# 0  94117.0  Entire home/apt             3        1.0       1.0   2.0
# 1  94110.0  Entire home/apt             5        1.0       2.0   3.0
# 2  94117.0     Private room             2        4.0       1.0   1.0
# 3  94117.0     Private room             2        4.0       1.0   1.0
# 4  94117.0  Entire home/apt             4        1.5       2.0   2.0
#
#    bed_type  minimum_nights  number_of_reviews
# 0  Real Bed               1                240
# 1  Real Bed              30                111
# 2  Real Bed              32                 19
# 3  Real Bed              32                  8
# 4  Real Bed               5                 28

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
#label_encoder = LabelEncoder()
#label_encoder.fit(data['room_type'])
#encoded_data = label_encoder.transform(data)
#encoded_data=OneHotEncoder().fit_transform(df[['room_type']])
encoded_data
# Out:
# <8076x4 sparse matrix of type '<class 'numpy.float64'>'
# 	with 8076 stored elements in Compressed Sparse Row format>

# %%
class MultiColumnLabelEncoder:
    def __init__(self,columns = None):
        self.columns = columns # array of column names to encode

    def fit(self,X,y=None):
        return self # not relevant here

    def transform(self,X):
        '''
        Transforms columns of X specified in self.columns using
        LabelEncoder(). If no columns specified, transforms all
        columns in X.
        '''
        output = X.copy()
        if self.columns is not None:
            for col in self.columns:
                output[col] = LabelEncoder().fit_transform(output[col])
        else:
            for colname,col in output.iteritems():
                output[colname] = LabelEncoder().fit_transform(col)
        return output

    def fit_transform(self,X,y=None):
        return self.fit(X,y).transform(X)

# %%
data2=MultiColumnLabelEncoder(columns = ['room_type', 'bed_type', 'zipcode']).fit_transform(data)

# %%
data2.groupby(['room_type','bed_type', 'zipcode' ]).count()
# Out:
#                             accommodates  bathrooms  bedrooms  beds  \
# room_type bed_type zipcode
# 0         0        8                   1          1         1     1
#                    18                  1          1         1     1
#                    23                  1          1         1     1
#           1        2                   1          1         1     1
#                    8                   1          1         1     1
# ...                                  ...        ...       ...   ...
# 3         4        18                  5          5         5     5
#                    20                  2          2         2     2
#                    24                  2          2         2     2
#                    25                 39         39        39    39
#                    27                  5          5         5     5
#
#                             minimum_nights  number_of_reviews
# room_type bed_type zipcode
# 0         0        8                     1                  1
#                    18                    1                  1
#                    23                    1                  1
#           1        2                     1                  1
#                    8                     1                  1
# ...                                    ...                ...
# 3         4        18                    5                  5
#                    20                    2                  2
#                    24                    2                  2
#                    25                   39                 39
#                    27                    5                  5
#
# [133 rows x 6 columns]

# %% [markdown]
# # Create a Train Test Split
#
# Use `price` for the y values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data2, target, random_state=42)

# %%
X_train.head()
# Out:
#       zipcode  room_type  accommodates  bathrooms  bedrooms  beds  bed_type  \
# 5692        1          1             2        1.0       1.0   1.0         4
# 5348       21          2             1        1.0       1.0   1.0         4
# 3600       12          0             2        1.0       1.0   1.0         4
# 1060        8          2             2        1.0       1.0   1.0         4
# 633         7          0             2        1.0       1.0   1.0         4
#
#       minimum_nights  number_of_reviews
# 5692               1                  0
# 5348              30                 14
# 3600               3                 86
# 1060               1                276
# 633                1                  8

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data

from sklearn.preprocessing import MinMaxScaler

X_minmax = MinMaxScaler().fit(X_train)

X_train_scaled = X_minmax.transform(X_train)
X_test_scaled= X_minmax.transform(X_test)

# %% [markdown]
# # Train the Model

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train_scaled, y_train)
# Out:
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
print(f"Training Data Score: {rf.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {rf.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.8353970612514446
# Testing Data Score: 0.10549777117384844

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.3562386674044273, 'number_of_reviews'),
#  (0.2688410223132107, 'zipcode'),
#  (0.09846596470812186, 'minimum_nights'),
#  (0.07837131149637973, 'accommodates'),
#  (0.07110303905932326, 'bathrooms'),
#  (0.07018236357286282, 'beds'),
#  (0.03313981190614952, 'bedrooms'),
#  (0.017646652979001875, 'room_type'),
#  (0.006011166560522911, 'bed_type')]

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'n_estimators': [250, 300, 350],
              'max_depth': [125, 150, 175]}
grid = GridSearchCV(rf, param_grid, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train_scaled, y_train)
# Out:
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/model_selection/_split.py:657: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=3.
#   % (min_groups, self.n_splits)), Warning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV] max_depth=125, n_estimators=250 .................................
# [CV] ..... max_depth=125, n_estimators=250, score=0.096, total=   8.0s
# [CV] max_depth=125, n_estimators=250 .................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    8.0s remaining:    0.0s
# [CV] ..... max_depth=125, n_estimators=250, score=0.114, total=  13.4s
# [CV] max_depth=125, n_estimators=250 .................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   21.6s remaining:    0.0s
# [CV] ..... max_depth=125, n_estimators=250, score=0.119, total=  13.2s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.095, total=   8.3s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.115, total=  15.7s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.118, total=  15.7s
# [CV] max_depth=125, n_estimators=350 .................................
# [CV] ..... max_depth=125, n_estimators=350, score=0.097, total=   9.6s
# [CV] max_depth=125, n_estimators=350 .................................
# [CV] ..... max_depth=125, n_estimators=350, score=0.116, total=  18.3s
# [CV] max_depth=125, n_estimators=350 .................................
# [CV] ..... max_depth=125, n_estimators=350, score=0.118, total=  18.4s
# [CV] max_depth=150, n_estimators=250 .................................
# [CV] ..... max_depth=150, n_estimators=250, score=0.096, total=   6.8s
# [CV] max_depth=150, n_estimators=250 .................................
# [CV] ..... max_depth=150, n_estimators=250, score=0.114, total=  11.8s
# [CV] max_depth=150, n_estimators=250 .................................
# [CV] ..... max_depth=150, n_estimators=250, score=0.117, total=  10.4s
# [CV] max_depth=150, n_estimators=300 .................................
# [CV] ..... max_depth=150, n_estimators=300, score=0.095, total=   7.0s
# [CV] max_depth=150, n_estimators=300 .................................
# [CV] ..... max_depth=150, n_estimators=300, score=0.116, total=  13.2s
# [CV] max_depth=150, n_estimators=300 .................................
# [CV] ..... max_depth=150, n_estimators=300, score=0.119, total=  13.7s
# [CV] max_depth=150, n_estimators=350 .................................
# [CV] ..... max_depth=150, n_estimators=350, score=0.098, total=   7.5s
# [CV] max_depth=150, n_estimators=350 .................................
# [CV] ..... max_depth=150, n_estimators=350, score=0.112, total=  15.8s
# [CV] max_depth=150, n_estimators=350 .................................
# [CV] ..... max_depth=150, n_estimators=350, score=0.121, total=  15.6s
# [CV] max_depth=175, n_estimators=250 .................................
# [CV] ..... max_depth=175, n_estimators=250, score=0.095, total=   5.3s
# [CV] max_depth=175, n_estimators=250 .................................
# [CV] ..... max_depth=175, n_estimators=250, score=0.116, total=  10.0s
# [CV] max_depth=175, n_estimators=250 .................................
# [CV] ..... max_depth=175, n_estimators=250, score=0.121, total=   9.8s
# [CV] max_depth=175, n_estimators=300 .................................
# [CV] ..... max_depth=175, n_estimators=300, score=0.096, total=   6.3s
# [CV] max_depth=175, n_estimators=300 .................................
# [CV] ..... max_depth=175, n_estimators=300, score=0.120, total=  12.5s
# [CV] max_depth=175, n_estimators=300 .................................
# [CV] ..... max_depth=175, n_estimators=300, score=0.116, total=  12.9s
# [CV] max_depth=175, n_estimators=350 .................................
# [CV] ..... max_depth=175, n_estimators=350, score=0.095, total=   7.8s
# [CV] max_depth=175, n_estimators=350 .................................
# [CV] ..... max_depth=175, n_estimators=350, score=0.114, total=  15.9s
# [CV] max_depth=175, n_estimators=350 .................................
# [CV] ..... max_depth=175, n_estimators=350, score=0.120, total=  16.7s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:  5.5min finished
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/model_selection/_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=RandomForestClassifier(bootstrap=True, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=10, n_jobs=None,
#                                               oob_score=False,
#                                               random_state=None, verbose=0,
#                                               warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid={'max_depth': [125, 150, 175],
#                          'n_estimators': [250, 300, 350]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'max_depth': 175, 'n_estimators': 250}
# 0.1099554234769688

# %%
# Training score:
grid.score(X_train_scaled, y_train)
# Out:
# 0.849925705794948

# %%
# Testing score:
grid.score(X_test_scaled, y_test)
# Out:
# 0.11391778107974244

# %%
# Make prediction and save to variable for report.
predictions = grid.predict(X_test_scaled)

# %%
# Print Classification Report
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#         1200       0.00      0.00      0.00         0
#         1900       0.00      0.00      0.00         0
#         2700       0.00      0.00      0.00         1
#         2900       0.00      0.00      0.00         1
#         3000       0.25      0.33      0.29         3
#         3100       0.00      0.00      0.00         1
#         3200       0.00      0.00      0.00         3
#         3300       0.12      0.20      0.15         5
#         3400       0.00      0.00      0.00         1
#         3500       0.00      0.00      0.00         1
#         3600       0.00      0.00      0.00         1
#         3700       0.00      0.00      0.00         2
#         3800       0.44      0.50      0.47         8
#         3900       0.50      0.20      0.29         5
#         4000       0.42      0.50      0.45        10
#         4100       0.00      0.00      0.00         1
#         4200       0.00      0.00      0.00         3
#         4300       0.50      1.00      0.67         2
#         4400       0.00      0.00      0.00         0
#         4500       0.55      0.55      0.55        20
#         4600       0.67      1.00      0.80         2
#         4700       0.00      0.00      0.00         2
#         4800       0.50      0.25      0.33         4
#         4900       0.25      0.33      0.29         6
#         5000       0.27      0.20      0.23        20
#         5100       0.00      0.00      0.00         1
#         5200       0.00      0.00      0.00         3
#         5300       0.00      0.00      0.00         2
#         5400       0.00      0.00      0.00         1
#         5500       0.29      0.40      0.33        15
#         5600       0.00      0.00      0.00         2
#         5700       0.00      0.00      0.00         1
#         5800       0.14      0.25      0.18         4
#         5900       0.00      0.00      0.00         7
#         6000       0.13      0.11      0.12        18
#         6100       0.00      0.00      0.00         1
#         6200       0.00      0.00      0.00         1
#         6300       0.33      0.25      0.29         4
#         6400       0.00      0.00      0.00         4
#         6500       0.11      0.10      0.10        21
#         6600       0.00      0.00      0.00         4
#         6700       0.38      0.50      0.43         6
#         6800       0.00      0.00      0.00         6
0.00      0.00      0.00         1
#        75000       0.00      0.00      0.00         4
#        75200       0.00      0.00      0.00         1
#        76000       0.00      0.00      0.00         1
#        77500       0.00      0.00      0.00         1
#        77600       0.00      0.00      0.00         0
#        79900       0.00      0.00      0.00         2
#        80000       0.00      0.00      0.00         4
#        82500       0.00      0.00      0.00         1
#        85000       0.00      0.00      0.00         1
#        87500       0.00      0.00      0.00         1
#        89900       0.00      0.00      0.00         1
#        90000       0.00      0.00      0.00         0
#        99000       0.50      1.00      0.67         1
#        99500       0.00      0.00      0.00         1
#        99800       0.00      0.00      0.00         2
#        99900       0.00      0.00      0.00         4
#       100000       0.00      0.00      0.00         7
#       102100       0.00      0.00      0.00         1
#       109500       0.00      0.00      0.00         1
#       109900       0.00      0.00      0.00         0
#       119900       0.00      0.00      0.00         1
#       120000       0.00      0.00      0.00         1
#       122900       0.00      0.00      0.00         1
#       125200       0.00      0.00      0.00         1
#       128700       0.00      0.00      0.00         0
#       129500       0.00      0.00      0.00         1
#       130000       0.50      1.00      0.67         1
#       130900       0.00      0.00      0.00         1
#       135000       0.00      0.00      0.00         1
#       140000       0.00      0.00      0.00         1
#       149500       0.00      0.00      0.00         1
#       149900       1.00      1.00      1.00         1
#       150000       0.00      0.00      0.00         4
#       160000       0.00      0.00      0.00         1
#       179500       0.00      0.00      0.00         1
#       180000       0.00      0.00      0.00         0
#       189500       0.00      0.00      0.00         0
#       199500       0.00      0.00      0.00         1
#       200000       0.00      0.00      0.00         2
#       201000       0.00      0.00      0.00         1
#       208200       0.00      0.00      0.00         1
#       245000       0.00      0.00      0.00         1
#       300000       0.00      0.00      0.00         1
#       302500       0.00      0.00      0.00         0
#       450000       0.00      0.00      0.00         1
#       455000       0.00      0.00      0.00         0
#       500000       0.00      0.00      0.00         1
#       999900       0.00      0.00      0.00         0
#      1000000       0.00      0.00      0.00         1
#
#     accuracy                           0.11      2019
#    macro avg       0.05      0.05      0.05      2019
# weighted avg       0.12      0.11      0.11      2019
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
# %matplotlib notebook
from yellowbrick.classifier import ClassificationReport
viz = ClassificationReport(RandomForestClassifier())
viz.fit(X_train_scaled, y_train)
viz.score(X_test_scaled, y_test)
viz.finalize()
viz.show(outpath="classificationreport.png")
# Out:
# <div id='5b62abce-5d3d-4dbb-adb4-5ed933fd5ce1'></div>
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-90-ee35c1908ba6> in <module>
#       3 viz = ClassificationReport(RandomForestClassifier())
#       4 viz.fit(X_train_scaled, y_train)
# ----> 5 viz.score(X_test_scaled, y_test)
#       6 viz.finalize()
#       7 viz.show(outpath="classificationreport.png")
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/yellowbrick/classifier/classification_report.py in score(self, X, y)
#     200             self.scores_.pop("support")
#     201
# --> 202         self.draw()
#     203         return self.score_
#     204
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/yellowbrick/classifier/classification_report.py in draw(self)
#     213         for idx, cls in enumerate(self.classes_):
#     214             for jdx, metric in enumerate(self._displayed_scores):
# --> 215                 cr_display[idx, jdx] = self.scores_[metric][cls]
#     216
#     217         # Set up the dimensions of the pcolormesh
#
# KeyError: 97500

# %%
from yellowbrick.model_selection import FeatureImportances
from yellowbrick.style import set_palette
from yellowbrick.features import RadViz
set_palette('yellowbrick')
viz = FeatureImportances(rf, size=(2000, 1500))
viz.fit(X_train_scaled, y_train)
viz.show(outpath="featureimportance.png")

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'models.sav'
joblib.dump(rf, filename)
# Out:
# ['models.sav']
